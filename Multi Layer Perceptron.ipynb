# %% [markdown]
# <b><h4>HW3 - Notebook: Multi-Layer perceptron</h4></b>
#
# [CE40477: Machine Learning](https://www.sharifml.ir/)
#
# __Course Instructor__: Dr. Sharifi-Zarchi
#
# __Notebook Authors__: Amir Ezzati & Ali Bavafa
#
# Name: Sina Daneshgar
# Student-ID: 401100369

# %% [markdown]
# # Import & Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gdown
from sklearn.datasets import fetch_openml
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import time
import random

import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import transforms
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset

from tqdm.auto import tqdm
from IPython.display import display

from torchvision import datasets, transforms

# %%
def seed_setter(seed=None, seed_torch=True):
  """
  Function that controls randomness.

  Args:
    seed : Integer
      A non-negative integer that defines the random state.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):

  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)


def train_test_classification(net, criterion, optimizer, train_loader,
                              test_loader, num_epochs=1, verbose=True,
                              training_plot=False):
  """
  Accumulate training loss/Evaluate performance

  Args:
    net: Instance of Net class
      Describes the model with ReLU activation, batch size 128
    criterion: torch.nn type
      Criterion combines LogSoftmax and NLLLoss in one single class.
    optimizer: torch.optim type
      Implements Adam algorithm.
    train_loader: torch.utils.data type
      Combines the train dataset and sampler, and provides an iterable over the given dataset.
    test_loader: torch.utils.data type
      Combines the test dataset and sampler, and provides an iterable over the given dataset.
    num_epochs: int
      Number of epochs [default: 1]
    verbose: boolean
      If True, print statistics
    training_plot=False
      If True, display training plot

  Returns:
    Nothing
  """
  net.train()
  train_losses = []
  for epoch in tqdm(range(num_epochs)):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
      # Get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      optimizer.zero_grad()
      outputs = net(inputs)

      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()

      if verbose:
        train_losses += [loss.item()]

  net.eval()

  def test(data_loader):
    """
    Function to gauge network performance

    Args:
      data_loader: torch.utils.data type
        Combines the test dataset and sampler, and provides an iterable over the given dataset.

    Returns:
      acc: float
        Performance of the network
      total: int
        Number of datapoints in the dataloader
    """
    correct = 0
    total = 0
    for data in data_loader:
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      outputs = net(inputs)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return total, acc

  train_total, train_acc = test(train_loader)
  test_total, test_acc = test(test_loader)

  if verbose:
    print(f'\nAccuracy on the {train_total} training samples: {train_acc:0.2f}')
    print(f'Accuracy on the {test_total} testing samples: {test_acc:0.2f}\n')

  if training_plot:
    plt.plot(train_losses)
    plt.xlabel('Batch')
    plt.ylabel('Training loss')
    plt.show()

  return train_acc, test_acc


def shuffle_and_split_data(X, y, seed):
  """
  Helper function to shuffle and split data

  Args:
    X: torch.tensor
      Input data
    y: torch.tensor
      Corresponding target variables
    seed: int
      Set seed for reproducibility

  Returns:
    X_test: torch.tensor
      Test data [20% of X]
    y_test: torch.tensor
      Labels corresponding to above mentioned test data
    X_train: torch.tensor
      Train data [80% of X]
    y_train: torch.tensor
      Labels corresponding to above mentioned train data
  """
  # Set seed for reproducibility
  torch.manual_seed(seed)
  # Number of samples
  N = X.shape[0]
  # Shuffle data
  shuffled_indices = torch.randperm(N)
  X = X[shuffled_indices]
  y = y[shuffled_indices]

  test_size = int(0.2 * N)
  X_test = X[:test_size]
  y_test = y[:test_size]
  X_train = X[test_size:]
  y_train = y[test_size:]

  return X_test, y_test, X_train, y_train


def sample_grid(M=500, x_max=2.0):
  """
  Helper function to simulate sample meshgrid

  Args:
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points

  Returns:
    X_all: torch.tensor
      Concatenated meshgrid tensor
  """
  ii, jj = torch.meshgrid(torch.linspace(-x_max, x_max,M),
                          torch.linspace(-x_max, x_max, M),
                          indexing='ij')
  X_all = torch.cat([ii.unsqueeze(-1),
                     jj.unsqueeze(-1)],
                     dim=-1).view(-1, 2)
  return X_all


def plot_decision_map(X_all, y_pred, X_test, y_test,
                      M=500, x_max=2.0, eps=1e-3):
  """
  Helper function to plot decision map

  Args:
    X_all: torch.tensor
      Concatenated meshgrid tensor
    y_pred: torch.tensor
      Labels predicted by the network
    X_test: torch.tensor
      Test data
    y_test: torch.tensor
      Labels of the test data
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points
    eps: float
      Decision threshold

  Returns:
    Nothing
  """
  decision_map = torch.argmax(y_pred, dim=1)

  for i in range(len(X_test)):
    indeces = (X_all[:, 0] - X_test[i, 0])**2 + (X_all[:, 1] - X_test[i, 1])**2 < eps
    decision_map[indeces] = (K + y_test[i]).long()

  decision_map = decision_map.view(M, M).cpu()
  plt.imshow(decision_map, extent=[-x_max, x_max, -x_max, x_max], cmap='jet')
  plt.axis('off')
  plt.plot()


def plot_function_apx(x_vals, relu_activations, predicted_output):
    """
    Visualizes ReLU activations and the resulting function approximation.

    Args:
      x_vals: torch.tensor
        Input x-axis data points.
      relu_activations: torch.tensor
        Calculated ReLU activations along x-axis for each ReLU unit.
      predicted_output: torch.tensor
        Estimated output labels or function approximations (weighted sum of ReLUs).

    Returns:
      None
    """

    fig, axes = plt.subplots(2, 1, figsize=(8, 6))

    ## Plot ReLU activations
    axes[0].plot(x_vals, relu_activations.T)
    axes[0].set_xlabel('x-values', fontsize=12)
    axes[0].set_ylabel('Activation Levels', fontsize=12)
    axes[0].set_title('ReLU Activations (Basis Functions)', fontsize=14)
    relu_labels = [f"ReLU {i + 1}" for i in range(relu_activations.shape[0])]
    axes[0].legend(relu_labels, ncol=2)

    ## Plot the function approximation and the ground truth
    axes[1].plot(x_vals, torch.sin(x_vals), label='Ground Truth (sin(x))', color='g', linewidth=2)
    axes[1].plot(x_vals, predicted_output, label='Predicted Output', linestyle='--', color='r')
    axes[1].set_xlabel('x-values', fontsize=12)
    axes[1].set_ylabel('y(x)', fontsize=12)
    axes[1].set_title('Function Approximation vs Ground Truth', fontsize=14)
    axes[1].legend()

    plt.tight_layout(pad=2)
    plt.show()


def show_images(image, num_row=2, num_col=5):
    # plot images
    image_size = int(np.sqrt(image.shape[-1]))
    image = np.reshape(image, (image.shape[0], image_size, image_size))
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
    for i in range(num_row*num_col):
        ax = axes[i//num_col, i%num_col]
        ax.imshow(image[i], cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    plt.tight_layout()
    plt.show()


SEED = 2024
# Call `seed_setter` to ensure reproducibility.
seed_setter(seed=SEED)
# Out:
# Random seed 2024 has been set.

# %% [markdown]
# # Loading the data

# %%
# Load data
mnist_data = fetch_openml("mnist_784")
x = mnist_data["data"].astype('float').to_numpy()
y = mnist_data["target"].astype('int')

# Normalize
x /= 255.0

# One-hot encode labels
num_labels = len(np.unique(y))
y_new = to_categorical(y, num_labels)

# -------------------------------- TODO -------------------------------------
# In this section, split the data into training and test datasets, using 60,000 samples for training and the remaining samples for testing.
x_train, x_test, y_train, y_test = train_test_split(x, y_new, train_size=60000, random_state=42)
# -------------------------------- TODO -------------------------------------

# %%
print("Training data: {} {}".format(x_train.shape, y_train.shape))
print("Test data: {} {}".format(x_test.shape, y_test.shape))
show_images(x_train)
# Out:
# Training data: (60000, 784) (60000, 10)
# Test data: (10000, 784) (10000, 10)

# %% [markdown]
# # Activation Functions & Optimizers

# %% [markdown]
# There are many activation functions which some of them listed below. In this section you should implement them.
#
# 1. Sigmoid:
# $$
# \operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}
# $$
#
# 2. Softmax: $$\operatorname{softmax}(\mathbf X)_{ij} = \frac{\exp(\mathbf X_{ij})}{\sum_k \exp \mathbf X_{ik})}.$$
#
#
# 3. Tanh (Hyperbolic Tangent):
# $$
# \operatorname{tanh}(x) = \frac{\sinh(x)}{\cosh(x)} = \frac{\exp(x) - \exp(-x)}{\exp(x) + \exp(-x)}
# $$
#
# 4. ReLU: $$\operatorname{ReLU}(x) = \max(0, x)$$
#
# 5. Leaky ReLU:
# $$
# \operatorname{LeakyReLU}(x) =
# \begin{cases}
# x & \text{if } x \geq 0 \\
# \alpha x & \text{if } x < 0
# \end{cases}
# $$
# where \( $\alpha$ \) is a small constant (e.g., 0.01).
#
# 6. ELU (Exponential Linear Unit):
# $$
# \operatorname{ELU}(x) =
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where ($\alpha$) is a positive constant.
#
# 7. SELU (Scaled Exponential Linear Unit):
# $$
# \operatorname{SELU}(x) =
# \lambda
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where \( $\lambda$ \) and \( $\alpha$ \) are predefined constants, typically \( $\lambda \approx 1.0507$ \) and \( $\alpha \approx 1.67326$ \).

# %% [markdown]
# ------
# There are several optimizer algorithms for optimizing the neural network over epochs. You should implement some of those mentioned in this section:
#
# ***Stochastic Gradient Descent (SGD)***
#
# SGD is the basic form of gradient descent, where each weight (\( w \)) and bias (\( b \)) parameter is updated in the opposite direction of its gradient.
#
# **Update Rule:**
# $$
# w^{(t+1)} = w^{(t)} - \eta \cdot \nabla_w L(w^{(t)}, b^{(t)})
# $$
# $$
# b^{(t+1)} = b^{(t)} - \eta \cdot \nabla_b L(w^{(t)}, b^{(t)})
# $$
#
# - \( w \): Weight parameters
# - \( b \): Bias parameters
# - \( $\eta$ \): Learning rate
# - \( $\nabla_w L(w, b)$ \): Gradient of the loss with respect to \( w \)
# - \( $\nabla_b L(w, b)$ \): Gradient of the loss with respect to \( b \)
#
# <br><br>
#
# ***Momentum Optimizer***
#
# Momentum optimizer smooths parameter updates by adding a velocity term to accumulate past gradients.
#
# **Update Rule:**
# 1. **Velocity Update for Weights and Biases:**
#    $$
#    v_w^{(t+1)} = \beta \cdot v_w^{(t)} + (1 - \beta) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_b^{(t+1)} = \beta \cdot v_b^{(t)} + (1 - \beta) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#
# 2. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot v_w^{(t+1)}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot v_b^{(t+1)}
#    $$
#
# - \( $v_w$ \): Velocity term for weights
# - \( $v_b$ \): Velocity term for biases
# - \( $\beta$ \): Momentum term, typically set to 0.9
#
# <br><br>
#
# ***Adam Optimizer***
#
# Adam combines momentum and adaptive learning rates, using both first (momentum) and second (RMSprop) moment estimates.
#
# **Update Rule:**
# 1. **Compute biased first and second moment estimates:**
#    $$
#    m_w^{(t+1)} = \beta_1 \cdot m_w^{(t)} + (1 - \beta_1) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    m_b^{(t+1)} = \beta_1 \cdot m_b^{(t)} + (1 - \beta_1) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_w^{(t+1)} = \beta_2 \cdot v_w^{(t)} + (1 - \beta_2) \cdot \left( \nabla_w L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#    $$
#    v_b^{(t+1)} = \beta_2 \cdot v_b^{(t)} + (1 - \beta_2) \cdot \left( \nabla_b L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#
# 2. **Compute bias-corrected estimates:**
#    $$
#    \hat{m}_w^{(t+1)} = \frac{m_w^{(t+1)}}{1 - \beta_1^{t+1}}, \quad \hat{m}_b^{(t+1)} = \frac{m_b^{(t+1)}}{1 - \beta_1^{t+1}}
#    $$
#    $$
#    \hat{v}_w^{(t+1)} = \frac{v_w^{(t+1)}}{1 - \beta_2^{t+1}}, \quad \hat{v}_b^{(t+1)} = \frac{v_b^{(t+1)}}{1 - \beta_2^{t+1}}
#    $$
#
# 3. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot \frac{\hat{m}_w^{(t+1)}}{\sqrt{\hat{v}_w^{(t+1)}} + \epsilon}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot \frac{\hat{m}_b^{(t+1)}}{\sqrt{\hat{v}_b^{(t+1)}} + \epsilon}
#    $$
#
# - \( $m_w$ \), \( $m_b$ \): First moment estimates (mean of gradients) for weights and biases
# - \( $v_w$ \), \( $v_b$ \): Second moment estimates (uncentered variance of gradients) for weights and biases
# - \( $\beta_1$ \): Decay rate for first moment, typically 0.9
# - \( $\beta_2$ \): Decay rate for second moment, typically 0.999
# - \( $\epsilon$ \): Small constant for numerical stability (e.g., \(10^{-8}\))

# %% [markdown]
# # MLP from Scratch

# %%
class MLP():
    def __init__(self, sizes, activation='sigmoid'):
        self.sizes = sizes
        self.num_layers = len(sizes) - 1  # number of layers excluding input
        self.activation_name = activation

        # Choose activation function
        if activation == 'relu':
            self.activation = self.relu
        elif activation == 'sigmoid':
            self.activation = self.sigmoid
        elif activation == 'tanh':
            self.activation = self.tanh
        # -------------------------------- TODO -------------------------------------

        # Do the same for other activation functions
        elif activation == 'elu':
            self.activation = self.elu
        elif activation == 'selu':
            self.activation = self.selu
        elif activation == 'softmax':
            self.activation = self.softmax
        elif activation == 'leaky_relu':
            self.activation = self.leaky_relu

        # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This activation function is currently not supported!")

        # Save all weights
        self.params = self.initialize()
        # Save all intermediate values, i.e. activations
        self.cache = {}

    # Activation functions remain the same as defined in your original code
    def relu(self, x, derivative=False):
        '''
            Forward path:
            relu(x) = max(0, x)
            In other word,
            relu(x) = 0, if x < 0
                    = x, if x >= 0

            Backward path:
            ∇relu(x) = 0, if x < 0
                     = 1, if x >=0
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, 0)
        else:
            return np.maximum(0, x)
        # -------------------------------- TODO -------------------------------------

    def tanh(self, x, derivative=False):
        '''
            Forward path:
            tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

            Backward path:
            ∇tanh(x) = 1 - tanh(x)^2
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return 1 - np.tanh(x)**2
        else:
            return np.tanh(x)
        # -------------------------------- TODO -------------------------------------

    def sigmoid(self, x, derivative=False):
        '''
            Forward path:
            σ(x) = 1 / 1+exp(-z)

            Backward path:
            ∇σ(x) = exp(-z) / (1+exp(-z))^2
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return self.sigmoid(x) * (1 - self.sigmoid(x))
        else:
            return 1 / (1 + np.exp(-x))
        # -------------------------------- TODO -------------------------------------

    def softmax(self, x):
        '''
            softmax(x) = exp(x) / ∑exp(x)
        '''
        # Numerically stable with large exponentials
        # -------------------------------- TODO -------------------------------------
        exp_x = np.exp(x - np.max(x))
        return exp_x / exp_x.sum(axis=0, keepdims=True)
        # -------------------------------- TODO -------------------------------------


    def leaky_relu(self, x, alpha=0.01, derivative=False):
        '''
            Forward path:
            leaky_relu(x) = x if x >= 0 else αx

            Backward path:
            ∇leaky_relu(x) = 1 if x >= 0 else α
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x >= 0, 1, alpha)
        else:
            return np.where(x >= 0, x, alpha*x)
        # -------------------------------- TODO -------------------------------------

    def elu(self, x, alpha=1.0, derivative=False):
        '''
            Forward path:
            elu(x) = x if x > 0 else α(exp(x) - 1)

            Backward path:
            ∇elu(x) = 1 if x > 0 else α * exp(x)
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha*np.exp(x))
        else:
            return np.where(x > 0, x, alpha(np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------


    def selu(self, x, lambda_=1.0507, alpha=1.67326, derivative=False):
        '''
            Forward path:
            selu(x) = λ * (x if x > 0 else α * (exp(x) - 1))

            Backward path:
            ∇selu(x) = λ * (1 if x > 0 else α * exp(x))
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return lambda_ * np.where(x > 0, 1, alpha*np.exp(x))
        else:
            return lambda_ * np.where(x > 0, x, alpha*(np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------


    def initialize(self):
        params = {}
        for i in range(1, self.num_layers + 1):
            input_layer = self.sizes[i - 1]
            output_layer = self.sizes[i]
            params[f"W{i}"] = np.random.randn(output_layer, input_layer) * np.sqrt(1. / input_layer)
            params[f"b{i}"] = np.zeros((output_layer, 1))
        return params

    def feed_forward(self, x):
        self.cache["A0"] = x.T
        # -------------------------------- TODO -------------------------------------
        # Perform feedforward pass through each hidden layer, applying weights, biases, and activation function

        for l in range(1, self.num_layers + 1):
        # linear step
          Z = self.params[f"W{l}"] @ self.cache[f"A{l-1}"] + self.params[f"b{l}"]
          self.cache[f"Z{l}"] = Z

        # activation step
          if l == self.num_layers:
            self.cache[f"A{l}"] = self.softmax(Z)
          else:
            self.cache[f"A{l}"] = self.activation(Z)
        # -------------------------------- TODO -------------------------------------

        return self.cache[f"A{self.num_layers}"]

    def back_propagate(self, y, output):
        current_batch_size = y.shape[0]
        grads = {}

        # -------------------------------- TODO -------------------------------------
        # Backpropagate gradients through Output layer and each hidden layers
        dA = -(y.T - output)

        for l in range(self.num_layers, 0, -1):
          Z = self.cache[f"Z{l}"]
          if self.activation_name == 'softmax' and l == self.num_layers:
            # direct gradient
            dZ = dA
          else:
            dZ = dA * self.activation(Z, derivative=True)

          dW = (1 / current_batch_size) * (dZ @ self.cache[f"A{l-1}"].T)
          db = (1 / current_batch_size) * np.sum(dZ, axis=1, keepdims=True)


          grads[f"dW{l}"] = dW
          grads[f"db{l}"] = db

          if l > 1:
            dA = self.params[f"W{l}"].T @ dZ
        # -------------------------------- TODO -------------------------------------

        self.grads = grads
        return self.grads


    def cross_entropy_loss(self, y, output):
        '''
            L(y, ŷ) = −∑ylog(ŷ).
        '''
        # -------------------------------- TODO -------------------------------------
        # Compute cross-entropy loss as the negative average log-likelihood of the correct labels
        output = np.clip(output, 1e-12, 1.0)
        l = -np.sum(y * np.log(output)) / y.shape[0]
        # -------------------------------- TODO -------------------------------------
        return l

    def initialize_momemtum_optimizer(self):
        momentum_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for momentum updates of weights and biases in each layer
            momentum_opt[f"dW{i}"] = np.zeros_like(self.params[f"W{i}"])
            momentum_opt[f"db{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return momentum_opt

    def initialize_adam_optimizer(self):
        adam_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for first and second moment estimates of weights and biases in each layer
            adam_opt[f"dW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"db{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return adam_opt

    def optimize(self, l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):

        if self.optimizer == "sgd":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for SGD
                self.params[key] -= l_rate * self.grads[f"d{key}"]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "momentum":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Momentum
                self.momentum_opt[f"d{key}"] = beta * self.momentum_opt[f"d{key}"] + (1 - beta) * self.grads[f"d{key}"]
                self.params[key] -= l_rate * self.momentum_opt[f"d{key}"]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "adam":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Adam
                self.adam_opt[f"m{key}"] = beta1 * self.adam_opt[f"m{key}"] + (1 - beta1) * self.grads[f"d{key}"]
                self.adam_opt[f"v{key}"] = beta2 * self.adam_opt[f"v{key}"] + (1 - beta2) * (self.grads[f"d{key}"] ** 2)

                m_hat = self.adam_opt[f"m{key}"] / (1 - beta1 ** t)
                v_hat = self.adam_opt[f"v{key}"] / (1 - beta2 ** t)

                self.params[key] -= l_rate * (m_hat / (np.sqrt(v_hat) + epsilon))
                # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This optimizer is currently not supported!")

    # Accuracy, loss, and training methods remain the same as defined in your original code


    def accuracy(self, y, output):
        # -------------------------------- TODO -------------------------------------
        # Calculate accuracy by comparing the pred and truth matrices
        acc = np.mean(np.argmax(y, axis=1) == np.argmax(output, axis=0))
        return acc
        # -------------------------------- TODO -------------------------------------

    def train(self, x_train, y_train, x_val, y_val, epochs=10,
              batch_size=64, optimizer='momentum', l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        # Hyperparameters
        self.epochs = epochs
        self.batch_size = batch_size
        num_batches = -(-x_train.shape[0] // self.batch_size)

        # Initialize optimizer
        self.optimizer = optimizer
        if self.optimizer == 'momentum':
          self.momemtum_opt = self.initialize_momemtum_optimizer()
        elif self.optimizer == 'adam':
          self.adam_opt = self.initialize_adam_optimizer()

        start_time = time.time()

        # Train
        for i in range(self.epochs):
            # Shuffle
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]

            for j in range(num_batches):
                # Batch
                begin = j * self.batch_size
                end = min(begin + self.batch_size, x_train.shape[0]-1)
                x = x_train_shuffled[begin:end]
                y = y_train_shuffled[begin:end]

                # Forward
                output = self.feed_forward(x)
                # Backprop
                grad = self.back_propagate(y, output)
                # Optimize
                self.optimize(l_rate=l_rate, beta=beta, beta1=beta1, beta2=beta2, epsilon=epsilon, t=t)

            # Evaluate performance
            # Training data
            output = self.feed_forward(x_train)
            train_acc = self.accuracy(y_train, output)
            train_loss = self.cross_entropy_loss(y_train, output)
            # Test data
            output = self.feed_forward(x_val)
            val_acc = self.accuracy(y_val, output)
            val_loss = self.cross_entropy_loss(y_val, output)
            print(f'Epoch {i+1}: {time.time()-start_time:.2f}s, train acc={train_acc:.2f}, train loss={train_loss:.2f}, '
                      f'validation acc={val_acc:.2f}, validation loss={val_loss:.2f}')

    def evaluate(self, x_test, y_test):
        # Test data
        output = self.feed_forward(x_test)
        test_acc = self.accuracy(y_test, output)
        test_loss = self.cross_entropy_loss(y_test, output)
        print(f'\nTest acc={test_acc:.2f}, Test loss={test_loss:.2f}')

# %% [markdown]
# Please run experiments with different combinations of optimizers (SGD, Momentum, and Adam) and activation functions (ReLU, Sigmoid, Tanh, Leaky ReLU, SELU, and ELU) over 20 epochs each. Consider networks with three layers (without input layer) whose number of neurons is 128, 64 and 10 respectively. Also consider two learning rates 0.01 and 0.001.
#
#
# After testing all combinations, report which combination of optimizer, activation function, and learning rate performs best.

# %%
# Run your experiments here ...
class SimpleNN(nn.Module):
    def __init__(self, activation_func):
        super(SimpleNN, self).__init__()
        self.layer1 = nn.Linear(784, 128)
        self.layer2 = nn.Linear(128, 64)
        self.layer3 = nn.Linear(64, 10)

        if activation_func == 'relu':
            self.activation = nn.ReLU()
        elif activation_func == 'sigmoid':
            self.activation = nn.Sigmoid()
        elif activation_func == 'tanh':
            self.activation = nn.Tanh()
        elif activation_func == 'leaky_relu':
            self.activation = nn.LeakyReLU()
        elif activation_func == 'selu':
            self.activation = nn.SELU()
        elif activation_func == 'elu':
            self.activation = nn.ELU()

    def forward(self, x):
        x = self.activation(self.layer1(x))
        x = self.activation(self.layer2(x))
        x = self.layer3(x)  # No activation on output layer
        return x

transform = transforms.Compose([transforms.ToTensor(), transforms.Lambda(lambda x: x.view(-1))])
train_data = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)

activation_functions = ['relu', 'sigmoid', 'tanh', 'leaky_relu', 'selu', 'elu']
optimizers = ['sgd', 'momentum', 'adam']
learning_rates = [0.01, 0.001]
epochs = 20

def run_experiment(activation_func, optimizer_type, learning_rate):
    model = SimpleNN(activation_func)

    if optimizer_type == 'sgd':
        optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    elif optimizer_type == 'momentum':
        optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
    elif optimizer_type == 'adam':
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    criterion = nn.CrossEntropyLoss()

    model.train()
    for epoch in range(epochs):
        running_loss = 0.0
        correct = 0
        total = 0
        for data, target in train_loader:
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(output, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()

        accuracy = correct / total
        print(f"Epoch {epoch+1}/{epochs}, Loss: {running_loss/len(train_loader):.4f}, Accuracy: {accuracy:.4f}")

    return accuracy

best_accuracy = 0
best_params = {}

for activation_func in activation_functions:
    for optimizer_type in optimizers:
        for learning_rate in learning_rates:
            print(f"\nTesting {activation_func} + {optimizer_type} + LR={learning_rate}")
            accuracy = run_experiment(activation_func, optimizer_type, learning_rate)

            if accuracy > best_accuracy:
                best_accuracy = accuracy
                best_params = {
                    'activation_func': activation_func,
                    'optimizer_type': optimizer_type,
                    'learning_rate': learning_rate
                }

print("\nBest Combination:")
print(f"Activation Function: {best_params['activation_func']}")
print(f"Optimizer: {best_params['optimizer_type']}")
print(f"Learning Rate: {best_params['learning_rate']}")
print(f"Best Accuracy: {best_accuracy:.4f}")
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 93.9MB/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 17.1MB/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 80.3MB/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 9.68MB/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
#
# Testing relu + sgd + LR=0.01
# Epoch 1/20, Loss: 1.7891, Accuracy: 0.5312
# Epoch 2/20, Loss: 0.5640, Accuracy: 0.8526
# Epoch 3/20, Loss: 0.3997, Accuracy: 0.8876
# Epoch 4/20, Loss: 0.3472, Accuracy: 0.9008
# Epoch 5/20, Loss: 0.3158, Accuracy: 0.9102
# Epoch 6/20, Loss: 0.2928, Accuracy: 0.9174
# Epoch 7/20, Loss: 0.2736, Accuracy: 0.9225
# Epoch 8/20, Loss: 0.2567, Accuracy: 0.9269
# Epoch 9/20, Loss: 0.2412, Accuracy: 0.9312
# Epoch 10/20, Loss: 0.2269, Accuracy: 0.9357
# Epoch 11/20, Loss: 0.2142, Accuracy: 0.9396
# Epoch 12/20, Loss: 0.2026, Accuracy: 0.9427
# Epoch 13/20, Loss: 0.1918, Accuracy: 0.9460
# Epoch 14/20, Loss: 0.1824, Accuracy: 0.9488
# Epoch 15/20, Loss: 0.1740, Accuracy: 0.9507
# Epoch 16/20, Loss: 0.1659, Accuracy: 0.9527
# Epoch 17/20, Loss: 0.1588, Accuracy: 0.9552
# Epoch 18/20, Loss: 0.1517, Accuracy: 0.9568
# Epoch 19/20, Loss: 0.1455, Accuracy: 0.9584
# Epoch 20/20, Loss: 0.1396, Accuracy: 0.9600
#
# Testing relu + sgd + LR=0.001
# Epoch 1/20, Loss: 2.2940, Accuracy: 0.1238
# Epoch 2/20, Loss: 2.2660, Accuracy: 0.2091
# Epoch 3/20, Loss: 2.2240, Accuracy: 0.4028
# Epoch 4/20, Loss: 2.1580, Accuracy: 0.4875
# Epoch 5/20, Loss: 2.0524, Accuracy: 0.5257
# Epoch 6/20, Loss: 1.8908, Accuracy: 0.5761
# Epoch 7/20, Loss: 1.6637, Accuracy: 0.6352
# Epoch 8/20, Loss: 1.3920, Accuracy: 0.6929
# Epoch 9/20, Loss: 1.1393, Accuracy: 0.7516
# Epoch 10/20, Loss: 0.9500, Accuracy: 0.7863
# Epoch 11/20, Loss: 0.8198, Accuracy: 0.8066
# Epoch 12/20, Loss: 0.7285, Accuracy: 0.8219
# Epoch 13/20, Loss: 0.6619, Accuracy: 0.8341
# Epoch 14/20, Loss: 0.6109, Accuracy: 0.8436
# Epoch 15/20, Loss: 0.5708, Accuracy: 0.8515
# Epoch 16/20, Loss: 0.5386, Accuracy: 0.8577
# Epoch 17/20, Loss: 0.5123, Accuracy: 0.8631
# Epoch 18/20, Loss: 0.4902, Accuracy: 0.8681
# Epoch 19/20, Loss: 0.4716, Accuracy: 0.8730
# Epoch 20/20, Loss: 0.4555, Accuracy: 0.8763
#
# Testing relu + momentum + LR=0.01
# Epoch 1/20, Loss: 0.5482, Accuracy: 0.8395
# Epoch 2/20, Loss: 0.1944, Accuracy: 0.9432
# Epoch 3/20, Loss: 0.1326, Accuracy: 0.9610
# Epoch 4/20, Loss: 0.0994, Accuracy: 0.9706
# Epoch 5/20, Loss: 0.0805, Accuracy: 0.9757
# Epoch 6/20, Loss: 0.0668, Accuracy: 0.9798
# Epoch 7/20, Loss: 0.0552, Accuracy: 0.9834
# Epoch 8/20, Loss: 0.0482, Accuracy: 0.9852
# Epoch 9/20, Loss: 0.0414, Accuracy: 0.9875
# Epoch 10/20, Loss: 0.0360, Accuracy: 0.9891
# Epoch 11/20, Loss: 0.0302, Accuracy: 0.9912
# Epoch 12/20, Loss: 0.0260, Accuracy: 0.9920
# Epoch 13/20, Loss: 0.0229, Accuracy: 0.9935
# Epoch 14/20, Loss: 0.0190, Accuracy: 0.9949
# Epoch 15/20, Loss: 0.0158, Accuracy: 0.9960
# Epoch 16/20, Loss: 0.0131, Accuracy: 0.9972
# Epoch 17/20, Loss: 0.0106, Accuracy: 0.9978
# Epoch 18/20, Loss: 0.0091, Accuracy: 0.9983
# Epoch 19/20, Loss: 0.0078, Accuracy: 0.9986
# Epoch 20/20, Loss: 0.0070, Accuracy: 0.9987
#
# Testing relu + momentum + LR=0.001
# Epoch 1/20, Loss: 1.7689, Accuracy: 0.5973
# Epoch 2/20, Loss: 0.5696, Accuracy: 0.8489
# Epoch 3/20, Loss: 0.4044, Accuracy: 0.8853
# Epoch 4/20, Loss: 0.3527, Accuracy: 0.9000
# Epoch 5/20, Loss: 0.3224, Accuracy: 0.9075
# Epoch 6/20, Loss: 0.2988, Accuracy: 0.9139
# Epoch 7/20, Loss: 0.2789, Accuracy: 0.9198
# Epoch 8/20, Loss: 0.2608, Accuracy: 0.9261
# Epoch 9/20, Loss: 0.2453, Accuracy: 0.9299
# Epoch 10/20, Loss: 0.2314, Accuracy: 0.9338
# Epoch 11/20, Loss: 0.2181, Accuracy: 0.9379
# Epoch 12/20, Loss: 0.2068, Accuracy: 0.9408
# Epoch 13/20, Loss: 0.1966, Accuracy: 0.9439
# Epoch 14/20, Loss: 0.1866, Accuracy: 0.9464
# Epoch 15/20, Loss: 0.1774, Accuracy: 0.9488
# Epoch 16/20, Loss: 0.1694, Accuracy: 0.9515
# Epoch 17/20, Loss: 0.1616, Accuracy: 0.9536
# Epoch 18/20, Loss: 0.1547, Accuracy: 0.9554
# Epoch 19/20, Loss: 0.1484, Accuracy: 0.9568
# Epoch 20/20, Loss: 0.1423, Accuracy: 0.9594
#
# Testing relu + adam + LR=0.01
# Epoch 1/20, Loss: 0.2415, Accuracy: 0.9263
# Epoch 2/20, Loss: 0.1447, Accuracy: 0.9588
# Epoch 3/20, Loss: 0.1265, Accuracy: 0.9646
# Epoch 4/20, Loss: 0.1077, Accuracy: 0.9692
# Epoch 5/20, Loss: 0.1004, Accuracy: 0.9730
# Epoch 6/20, Loss: 0.0907, Accuracy: 0.9759
# Epoch 7/20, Loss: 0.0879, Accuracy: 0.9767
# Epoch 8/20, Loss: 0.0844, Accuracy: 0.9785
# Epoch 9/20, Loss: 0.0787, Accuracy: 0.9794
# Epoch 10/20, Loss: 0.0796, Accuracy: 0.9801
# Epoch 11/20, Loss: 0.0717, Accuracy: 0.9816
# Epoch 12/20, Loss: 0.0691, Accuracy: 0.9829
# Epoch 13/20, Loss: 0.0655, Accuracy: 0.9830
# Epoch 14/20, Loss: 0.0709, Accuracy: 0.9826
# Epoch 15/20, Loss: 0.0649, Accuracy: 0.9840
# Epoch 16/20, Loss: 0.0568, Accuracy: 0.9858
# Epoch 17/20, Loss: 0.0675, Accuracy: 0.9846
# Epoch 18/20, Loss: 0.0624, Accuracy: 0.9848
# Epoch 19/20, Loss: 0.0597, Accuracy: 0.9856
# Epoch 20/20, Loss: 0.0656, Accuracy: 0.9857
#
# Testing relu + adam + LR=0.001
# Epoch 1/20, Loss: 0.3396, Accuracy: 0.9063
# Epoch 2/20, Loss: 0.1358, Accuracy: 0.9592
# Epoch 3/20, Loss: 0.0942, Accuracy: 0.9714
# Epoch 4/20, Loss: 0.0699, Accuracy: 0.9787
# Epoch 5/20, Loss: 0.0535, Accuracy: 0.9837
# Epoch 6/20, Loss: 0.0448, Accuracy: 0.9857
# Epoch 7/20, Loss: 0.0353, Accuracy: 0.9889
# Epoch 8/20, Loss: 0.0300, Accuracy: 0.9904
# Epoch 9/20, Loss: 0.0234, Accuracy: 0.9929
# Epoch 10/20, Loss: 0.0215, Accuracy: 0.9926
# Epoch 11/20, Loss: 0.0183, Accuracy: 0.9942
# Epoch 12/20, Loss: 0.0142, Accuracy: 0.9956
# Epoch 13/20, Loss: 0.0170, Accuracy: 0.9946
# Epoch 14/20, Loss: 0.0109, Accuracy: 0.9966
# Epoch 15/20, Loss: 0.0125, Accuracy: 0.9956
# Epoch 16/20, Loss: 0.0112, Accuracy: 0.9961
# Epoch 17/20, Loss: 0.0079, Accuracy: 0.9975
# Epoch 18/20, Loss: 0.0102, Accuracy: 0.9968
# Epoch 19/20, Loss: 0.0087, Accuracy: 0.9971
# Epoch 20/20, Loss: 0.0093, Accuracy: 0.9967
#
# Testing sigmoid + sgd + LR=0.01
# Epoch 1/20, Loss: 2.3012, Accuracy: 0.1115
# Epoch 2/20, Loss: 2.2940, Accuracy: 0.1160
# Epoch 3/20, Loss: 2.2864, Accuracy: 0.1328
# Epoch 4/20, Loss: 2.2737, Accuracy: 0.1624
# Epoch 5/20, Loss: 2.2499, Accuracy: 0.2614
# Epoch 6/20, Loss: 2.1960, Accuracy: 0.3555
# Epoch 7/20, Loss: 2.0688, Accuracy: 0.4181
# Epoch 8/20, Loss: 1.8390, Accuracy: 0.4793
# Epoch 9/20, Loss: 1.5689, Accuracy: 0.5496
# Epoch 10/20, Loss: 1.3271, Accuracy: 0.6076
# Epoch 11/20, Loss: 1.1405, Accuracy: 0.6547
# Epoch 12/20, Loss: 1.0054, Accuracy: 0.6966
# Epoch 13/20, Loss: 0.9078, Accuracy: 0.7283
# Epoch 14/20, Loss: 0.8338, Accuracy: 0.7532
# Epoch 15/20, Loss: 0.7734, Accuracy: 0.7748
# Epoch 16/20, Loss: 0.7221, Accuracy: 0.7922
# Epoch 17/20, Loss: 0.6776, Accuracy: 0.8064
# Epoch 18/20, Loss: 0.6389, Accuracy: 0.8181
# Epoch 19/20, Loss: 0.6049, Accuracy: 0.8287
# Epoch 20/20, Loss: 0.5751, Accuracy: 0.8373
#
# Testing sigmoid + sgd + LR=0.001
# Epoch 1/20, Loss: 2.3176, Accuracy: 0.1078
# Epoch 2/20, Loss: 2.3011, Accuracy: 0.1124
# Epoch 3/20, Loss: 2.2997, Accuracy: 0.1124
# Epoch 4/20, Loss: 2.2992, Accuracy: 0.1124
# Epoch 5/20, Loss: 2.2986, Accuracy: 0.1124
# Epoch 6/20, Loss: 2.2981, Accuracy: 0.1124
# Epoch 7/20, Loss: 2.2976, Accuracy: 0.1124
# Epoch 8/20, Loss: 2.2970, Accuracy: 0.1124
# Epoch 9/20, Loss: 2.2964, Accuracy: 0.1124
# Epoch 10/20, Loss: 2.2958, Accuracy: 0.1124
# Epoch 11/20, Loss: 2.2953, Accuracy: 0.1124
# Epoch 12/20, Loss: 2.2946, Accuracy: 0.1124
# Epoch 13/20, Loss: 2.2940, Accuracy: 0.1124
# Epoch 14/20, Loss: 2.2934, Accuracy: 0.1124
# Epoch 15/20, Loss: 2.2927, Accuracy: 0.1124
# Epoch 16/20, Loss: 2.2920, Accuracy: 0.1124
# Epoch 17/20, Loss: 2.2913, Accuracy: 0.1124
# Epoch 18/20, Loss: 2.2905, Accuracy: 0.1124
# Epoch 19/20, Loss: 2.2897, Accuracy: 0.1124
# Epoch 20/20, Loss: 2.2889, Accuracy: 0.1124
#
# Testing sigmoid + momentum + LR=0.01
# Epoch 1/20, Loss: 2.0634, Accuracy: 0.2856
# Epoch 2/20, Loss: 0.8431, Accuracy: 0.7442
# Epoch 3/20, Loss: 0.5072, Accuracy: 0.8586
# Epoch 4/20, Loss: 0.3842, Accuracy: 0.8925
# Epoch 5/20, Loss: 0.3291, Accuracy: 0.9054
# Epoch 6/20, Loss: 0.2979, Accuracy: 0.9141
# Epoch 7/20, Loss: 0.2729, Accuracy: 0.9215
# Epoch 8/20, Loss: 0.2518, Accuracy: 0.9274
# Epoch 9/20, Loss: 0.2328, Accuracy: 0.9330
# Epoch 10/20, Loss: 0.2157, Accuracy: 0.9373
# Epoch 11/20, Loss: 0.2012, Accuracy: 0.9419
# Epoch 12/20, Loss: 0.1875, Accuracy: 0.9462
# Epoch 13/20, Loss: 0.1752, Accuracy: 0.9493
# Epoch 14/20, Loss: 0.1651, Accuracy: 0.9521
# Epoch 15/20, Loss: 0.1557, Accuracy: 0.9550
# Epoch 16/20, Loss: 0.1469, Accuracy: 0.9574
# Epoch 17/20, Loss: 0.1393, Accuracy: 0.9594
# Epoch 18/20, Loss: 0.1324, Accuracy: 0.9618
# Epoch 19/20, Loss: 0.1253, Accuracy: 0.9636
# Epoch 20/20, Loss: 0.1195, Accuracy: 0.9656
#
# Testing sigmoid + momentum + LR=0.001
# Epoch 1/20, Loss: 2.3009, Accuracy: 0.1143
# Epoch 2/20, Loss: 2.2932, Accuracy: 0.1241
# Epoch 3/20, Loss: 2.2847, Accuracy: 0.1408
# Epoch 4/20, Loss: 2.2702, Accuracy: 0.1868
# Epoch 5/20, Loss: 2.2412, Accuracy: 0.2681
# Epoch 6/20, Loss: 2.1735, Accuracy: 0.3384
# Epoch 7/20, Loss: 2.0171, Accuracy: 0.3942
# Epoch 8/20, Loss: 1.7640, Accuracy: 0.4592
# Epoch 9/20, Loss: 1.5177, Accuracy: 0.5302
# Epoch 10/20, Loss: 1.3334, Accuracy: 0.5851
# Epoch 11/20, Loss: 1.1832, Accuracy: 0.6345
# Epoch 12/20, Loss: 1.0544, Accuracy: 0.6764
# Epoch 13/20, Loss: 0.9533, Accuracy: 0.7090
# Epoch 14/20, Loss: 0.8763, Accuracy: 0.7351
# Epoch 15/20, Loss: 0.8148, Accuracy: 0.7574
# Epoch 16/20, Loss: 0.7625, Accuracy: 0.7755
# Epoch 17/20, Loss: 0.7162, Accuracy: 0.7918
# Epoch 18/20, Loss: 0.6745, Accuracy: 0.8054
# Epoch 19/20, Loss: 0.6371, Accuracy: 0.8175
# Epoch 20/20, Loss: 0.6040, Accuracy: 0.8276
#
# Testing sigmoid + adam + LR=0.01
# Epoch 1/20, Loss: 0.2664, Accuracy: 0.9196
# Epoch 2/20, Loss: 0.1120, Accuracy: 0.9654
# Epoch 3/20, Loss: 0.0878, Accuracy: 0.9722
# Epoch 4/20, Loss: 0.0760, Accuracy: 0.9757
# Epoch 5/20, Loss: 0.0666, Accuracy: 0.9788
# Epoch 6/20, Loss: 0.0607, Accuracy: 0.9796
# Epoch 7/20, Loss: 0.0550, Accuracy: 0.9821
# Epoch 8/20, Loss: 0.0535, Accuracy: 0.9824
# Epoch 9/20, Loss: 0.0478, Accuracy: 0.9847
# Epoch 10/20, Loss: 0.0458, Accuracy: 0.9848
# Epoch 11/20, Loss: 0.0427, Accuracy: 0.9863
# Epoch 12/20, Loss: 0.0423, Accuracy: 0.9864
# Epoch 13/20, Loss: 0.0388, Accuracy: 0.9874
# Epoch 14/20, Loss: 0.0383, Accuracy: 0.9872
# Epoch 15/20, Loss: 0.0346, Accuracy: 0.9890
# Epoch 16/20, Loss: 0.0398, Accuracy: 0.9872
# Epoch 17/20, Loss: 0.0332, Accuracy: 0.9892
# Epoch 18/20, Loss: 0.0333, Accuracy: 0.9890
# Epoch 19/20, Loss: 0.0319, Accuracy: 0.9892
# Epoch 20/20, Loss: 0.0316, Accuracy: 0.9893
#
# Testing sigmoid + adam + LR=0.001
# Epoch 1/20, Loss: 0.7070, Accuracy: 0.8113
# Epoch 2/20, Loss: 0.2253, Accuracy: 0.9363
# Epoch 3/20, Loss: 0.1564, Accuracy: 0.9546
# Epoch 4/20, Loss: 0.1188, Accuracy: 0.9660
# Epoch 5/20, Loss: 0.0947, Accuracy: 0.9732
# Epoch 6/20, Loss: 0.0772, Accuracy: 0.9776
# Epoch 7/20, Loss: 0.0644, Accuracy: 0.9816
# Epoch 8/20, Loss: 0.0536, Accuracy: 0.9847
# Epoch 9/20, Loss: 0.0443, Accuracy: 0.9877
# Epoch 10/20, Loss: 0.0373, Accuracy: 0.9896
# Epoch 11/20, Loss: 0.0306, Accuracy: 0.9918
# Epoch 12/20, Loss: 0.0257, Accuracy: 0.9931
# Epoch 13/20, Loss: 0.0212, Accuracy: 0.9949
# Epoch 14/20, Loss: 0.0174, Accuracy: 0.9960
# Epoch 15/20, Loss: 0.0143, Accuracy: 0.9967
# Epoch 16/20, Loss: 0.0117, Accuracy: 0.9976
# Epoch 17/20, Loss: 0.0092, Accuracy: 0.9984
# Epoch 18/20, Loss: 0.0079, Accuracy: 0.9986
# Epoch 19/20, Loss: 0.0065, Accuracy: 0.9989
# Epoch 20/20, Loss: 0.0052, Accuracy: 0.9991
#
# Testing tanh + sgd + LR=0.01
# Epoch 1/20, Loss: 1.4226, Accuracy: 0.6730
# Epoch 2/20, Loss: 0.5717, Accuracy: 0.8586
# Epoch 3/20, Loss: 0.4202, Accuracy: 0.8871
# Epoch 4/20, Loss: 0.3614, Accuracy: 0.8997
# Epoch 5/20, Loss: 0.3286, Accuracy: 0.9070
# Epoch 6/20, Loss: 0.3061, Accuracy: 0.9127
# Epoch 7/20, Loss: 0.2890, Accuracy: 0.9175
# Epoch 8/20, Loss: 0.2750, Accuracy: 0.9214
# Epoch 9/20, Loss: 0.2626, Accuracy: 0.9248
# Epoch 10/20, Loss: 0.2517, Accuracy: 0.9280
# Epoch 11/20, Loss: 0.2417, Accuracy: 0.9305
# Epoch 12/20, Loss: 0.2324, Accuracy: 0.9336
# Epoch 13/20, Loss: 0.2236, Accuracy: 0.9363
# Epoch 14/20, Loss: 0.2153, Accuracy: 0.9383
# Epoch 15/20, Loss: 0.2074, Accuracy: 0.9409
# Epoch 16/20, Loss: 0.1999, Accuracy: 0.9434
# Epoch 17/20, Loss: 0.1926, Accuracy: 0.9449
# Epoch 18/20, Loss: 0.1860, Accuracy: 0.9469
# Epoch 19/20, Loss: 0.1797, Accuracy: 0.9491
# Epoch 20/20, Loss: 0.1739, Accuracy: 0.9505
#
# Testing tanh + sgd + LR=0.001
# Epoch 1/20, Loss: 2.2474, Accuracy: 0.2750
# Epoch 2/20, Loss: 2.1107, Accuracy: 0.5900
# Epoch 3/20, Loss: 1.9224, Accuracy: 0.6728
# Epoch 4/20, Loss: 1.6761, Accuracy: 0.7005
# Epoch 5/20, Loss: 1.4243, Accuracy: 0.7201
# Epoch 6/20, Loss: 1.2149, Accuracy: 0.7491
# Epoch 7/20, Loss: 1.0551, Accuracy: 0.7755
# Epoch 8/20, Loss: 0.9347, Accuracy: 0.7971
# Epoch 9/20, Loss: 0.8420, Accuracy: 0.8116
# Epoch 10/20, Loss: 0.7691, Accuracy: 0.8242
# Epoch 11/20, Loss: 0.7104, Accuracy: 0.8343
# Epoch 12/20, Loss: 0.6621, Accuracy: 0.8436
# Epoch 13/20, Loss: 0.6219, Accuracy: 0.8504
# Epoch 14/20, Loss: 0.5883, Accuracy: 0.8569
# Epoch 15/20, Loss: 0.5596, Accuracy: 0.8618
# Epoch 16/20, Loss: 0.5348, Accuracy: 0.8664
# Epoch 17/20, Loss: 0.5133, Accuracy: 0.8710
# Epoch 18/20, Loss: 0.4944, Accuracy: 0.8747
# Epoch 19/20, Loss: 0.4779, Accuracy: 0.8775
# Epoch 20/20, Loss: 0.4633, Accuracy: 0.8803
#
# Testing tanh + momentum + LR=0.01
# Epoch 1/20, Loss: 0.4944, Accuracy: 0.8640
# Epoch 2/20, Loss: 0.2249, Accuracy: 0.9344
# Epoch 3/20, Loss: 0.1675, Accuracy: 0.9512
# Epoch 4/20, Loss: 0.1331, Accuracy: 0.9612
# Epoch 5/20, Loss: 0.1087, Accuracy: 0.9675
# Epoch 6/20, Loss: 0.0934, Accuracy: 0.9718
# Epoch 7/20, Loss: 0.0800, Accuracy: 0.9764
# Epoch 8/20, Loss: 0.0692, Accuracy: 0.9792
# Epoch 9/20, Loss: 0.0610, Accuracy: 0.9821
# Epoch 10/20, Loss: 0.0531, Accuracy: 0.9849
# Epoch 11/20, Loss: 0.0470, Accuracy: 0.9865
# Epoch 12/20, Loss: 0.0414, Accuracy: 0.9882
# Epoch 13/20, Loss: 0.0372, Accuracy: 0.9898
# Epoch 14/20, Loss: 0.0335, Accuracy: 0.9908
# Epoch 15/20, Loss: 0.0293, Accuracy: 0.9923
# Epoch 16/20, Loss: 0.0257, Accuracy: 0.9936
# Epoch 17/20, Loss: 0.0227, Accuracy: 0.9949
# Epoch 18/20, Loss: 0.0212, Accuracy: 0.9950
# Epoch 19/20, Loss: 0.0181, Accuracy: 0.9960
# Epoch 20/20, Loss: 0.0161, Accuracy: 0.9968
#
# Testing tanh + momentum + LR=0.001
# Epoch 1/20, Loss: 1.4476, Accuracy: 0.6644
# Epoch 2/20, Loss: 0.5796, Accuracy: 0.8563
# Epoch 3/20, Loss: 0.4201, Accuracy: 0.8875
# Epoch 4/20, Loss: 0.3605, Accuracy: 0.9001
# Epoch 5/20, Loss: 0.3280, Accuracy: 0.9068
# Epoch 6/20, Loss: 0.3060, Accuracy: 0.9125
# Epoch 7/20, Loss: 0.2889, Accuracy: 0.9172
# Epoch 8/20, Loss: 0.2746, Accuracy: 0.9214
# Epoch 9/20, Loss: 0.2621, Accuracy: 0.9248
# Epoch 10/20, Loss: 0.2513, Accuracy: 0.9279
# Epoch 11/20, Loss: 0.2409, Accuracy: 0.9303
# Epoch 12/20, Loss: 0.2311, Accuracy: 0.9334
# Epoch 13/20, Loss: 0.2222, Accuracy: 0.9363
# Epoch 14/20, Loss: 0.2139, Accuracy: 0.9386
# Epoch 15/20, Loss: 0.2059, Accuracy: 0.9409
# Epoch 16/20, Loss: 0.1987, Accuracy: 0.9432
# Epoch 17/20, Loss: 0.1913, Accuracy: 0.9455
# Epoch 18/20, Loss: 0.1846, Accuracy: 0.9476
# Epoch 19/20, Loss: 0.1784, Accuracy: 0.9494
# Epoch 20/20, Loss: 0.1724, Accuracy: 0.9510
#
# Testing tanh + adam + LR=0.01
# Epoch 1/20, Loss: 0.2683, Accuracy: 0.9187
# Epoch 2/20, Loss: 0.1939, Accuracy: 0.9414
# Epoch 3/20, Loss: 0.1908, Accuracy: 0.9434
# Epoch 4/20, Loss: 0.1868, Accuracy: 0.9435
# Epoch 5/20, Loss: 0.1768, Accuracy: 0.9467
# Epoch 6/20, Loss: 0.1752, Accuracy: 0.9477
# Epoch 7/20, Loss: 0.1619, Accuracy: 0.9517
# Epoch 8/20, Loss: 0.1623, Accuracy: 0.9516
# Epoch 9/20, Loss: 0.1680, Accuracy: 0.9498
# Epoch 10/20, Loss: 0.1691, Accuracy: 0.9491
# Epoch 11/20, Loss: 0.1562, Accuracy: 0.9534
# Epoch 12/20, Loss: 0.1630, Accuracy: 0.9515
# Epoch 13/20, Loss: 0.1576, Accuracy: 0.9533
# Epoch 14/20, Loss: 0.1597, Accuracy: 0.9526
# Epoch 15/20, Loss: 0.1589, Accuracy: 0.9528
# Epoch 16/20, Loss: 0.1472, Accuracy: 0.9561
# Epoch 17/20, Loss: 0.1519, Accuracy: 0.9544
# Epoch 18/20, Loss: 0.1488, Accuracy: 0.9558
# Epoch 19/20, Loss: 0.1559, Accuracy: 0.9546
# Epoch 20/20, Loss: 0.1524, Accuracy: 0.9538
#
# Testing tanh + adam + LR=0.001
# Epoch 1/20, Loss: 0.3283, Accuracy: 0.9106
# Epoch 2/20, Loss: 0.1364, Accuracy: 0.9593
# Epoch 3/20, Loss: 0.0922, Accuracy: 0.9717
# Epoch 4/20, Loss: 0.0677, Accuracy: 0.9789
# Epoch 5/20, Loss: 0.0521, Accuracy: 0.9836
# Epoch 6/20, Loss: 0.0383, Accuracy: 0.9884
# Epoch 7/20, Loss: 0.0324, Accuracy: 0.9899
# Epoch 8/20, Loss: 0.0249, Accuracy: 0.9928
# Epoch 9/20, Loss: 0.0187, Accuracy: 0.9947
# Epoch 10/20, Loss: 0.0173, Accuracy: 0.9946
# Epoch 11/20, Loss: 0.0122, Accuracy: 0.9962
# Epoch 12/20, Loss: 0.0120, Accuracy: 0.9961
# Epoch 13/20, Loss: 0.0124, Accuracy: 0.9962
# Epoch 14/20, Loss: 0.0094, Accuracy: 0.9970
# Epoch 15/20, Loss: 0.0102, Accuracy: 0.9965
# Epoch 16/20, Loss: 0.0038, Accuracy: 0.9992
# Epoch 17/20, Loss: 0.0088, Accuracy: 0.9972
# Epoch 18/20, Loss: 0.0083, Accuracy: 0.9972
# Epoch 19/20, Loss: 0.0046, Accuracy: 0.9987
# Epoch 20/20, Loss: 0.0030, Accuracy: 0.9994
#
# Testing leaky_relu + sgd + LR=0.01
# Epoch 1/20, Loss: 1.7539, Accuracy: 0.5353
# Epoch 2/20, Loss: 0.5804, Accuracy: 0.8538
# Epoch 3/20, Loss: 0.3999, Accuracy: 0.8883
# Epoch 4/20, Loss: 0.3483, Accuracy: 0.9006
# Epoch 5/20, Loss: 0.3203, Accuracy: 0.9087
# Epoch 6/20, Loss: 0.3000, Accuracy: 0.9144
# Epoch 7/20, Loss: 0.2830, Accuracy: 0.9187
# Epoch 8/20, Loss: 0.2675, Accuracy: 0.9233
# Epoch 9/20, Loss: 0.2531, Accuracy: 0.9280
# Epoch 10/20, Loss: 0.2394, Accuracy: 0.9325
# Epoch 11/20, Loss: 0.2265, Accuracy: 0.9350
# Epoch 12/20, Loss: 0.2140, Accuracy: 0.9395
# Epoch 13/20, Loss: 0.2028, Accuracy: 0.9425
# Epoch 14/20, Loss: 0.1921, Accuracy: 0.9458
# Epoch 15/20, Loss: 0.1822, Accuracy: 0.9484
# Epoch 16/20, Loss: 0.1730, Accuracy: 0.9509
# Epoch 17/20, Loss: 0.1647, Accuracy: 0.9530
# Epoch 18/20, Loss: 0.1567, Accuracy: 0.9554
# Epoch 19/20, Loss: 0.1496, Accuracy: 0.9578
# Epoch 20/20, Loss: 0.1430, Accuracy: 0.9593
#
# Testing leaky_relu + sgd + LR=0.001
# Epoch 1/20, Loss: 2.2986, Accuracy: 0.1435
# Epoch 2/20, Loss: 2.2687, Accuracy: 0.2198
# Epoch 3/20, Loss: 2.2217, Accuracy: 0.3689
# Epoch 4/20, Loss: 2.1440, Accuracy: 0.5177
# Epoch 5/20, Loss: 2.0165, Accuracy: 0.6030
# Epoch 6/20, Loss: 1.8181, Accuracy: 0.6515
# Epoch 7/20, Loss: 1.5511, Accuracy: 0.6962
# Epoch 8/20, Loss: 1.2695, Accuracy: 0.7320
# Epoch 9/20, Loss: 1.0439, Accuracy: 0.7608
# Epoch 10/20, Loss: 0.8877, Accuracy: 0.7845
# Epoch 11/20, Loss: 0.7807, Accuracy: 0.8027
# Epoch 12/20, Loss: 0.7041, Accuracy: 0.8178
# Epoch 13/20, Loss: 0.6465, Accuracy: 0.8298
# Epoch 14/20, Loss: 0.6018, Accuracy: 0.8396
# Epoch 15/20, Loss: 0.5661, Accuracy: 0.8471
# Epoch 16/20, Loss: 0.5370, Accuracy: 0.8536
# Epoch 17/20, Loss: 0.5127, Accuracy: 0.8601
# Epoch 18/20, Loss: 0.4923, Accuracy: 0.8643
# Epoch 19/20, Loss: 0.4749, Accuracy: 0.8685
# Epoch 20/20, Loss: 0.4599, Accuracy: 0.8725
#
# Testing leaky_relu + momentum + LR=0.01
# Epoch 1/20, Loss: 0.5520, Accuracy: 0.8363
# Epoch 2/20, Loss: 0.1926, Accuracy: 0.9436
# Epoch 3/20, Loss: 0.1332, Accuracy: 0.9606
# Epoch 4/20, Loss: 0.1012, Accuracy: 0.9698
# Epoch 5/20, Loss: 0.0827, Accuracy: 0.9754
# Epoch 6/20, Loss: 0.0687, Accuracy: 0.9800
# Epoch 7/20, Loss: 0.0582, Accuracy: 0.9825
# Epoch 8/20, Loss: 0.0510, Accuracy: 0.9847
# Epoch 9/20, Loss: 0.0438, Accuracy: 0.9869
# Epoch 10/20, Loss: 0.0376, Accuracy: 0.9883
# Epoch 11/20, Loss: 0.0320, Accuracy: 0.9902
# Epoch 12/20, Loss: 0.0278, Accuracy: 0.9919
# Epoch 13/20, Loss: 0.0238, Accuracy: 0.9934
# Epoch 14/20, Loss: 0.0214, Accuracy: 0.9939
# Epoch 15/20, Loss: 0.0170, Accuracy: 0.9955
# Epoch 16/20, Loss: 0.0152, Accuracy: 0.9957
# Epoch 17/20, Loss: 0.0123, Accuracy: 0.9970
# Epoch 18/20, Loss: 0.0100, Accuracy: 0.9978
# Epoch 19/20, Loss: 0.0079, Accuracy: 0.9986
# Epoch 20/20, Loss: 0.0070, Accuracy: 0.9988
#
# Testing leaky_relu + momentum + LR=0.001
# Epoch 1/20, Loss: 1.8394, Accuracy: 0.5484
# Epoch 2/20, Loss: 0.5923, Accuracy: 0.8431
# Epoch 3/20, Loss: 0.4086, Accuracy: 0.8856
# Epoch 4/20, Loss: 0.3515, Accuracy: 0.8997
# Epoch 5/20, Loss: 0.3203, Accuracy: 0.9084
# Epoch 6/20, Loss: 0.2974, Accuracy: 0.9149
# Epoch 7/20, Loss: 0.2784, Accuracy: 0.9205
# Epoch 8/20, Loss: 0.2620, Accuracy: 0.9253
# Epoch 9/20, Loss: 0.2468, Accuracy: 0.9293
# Epoch 10/20, Loss: 0.2334, Accuracy: 0.9335
# Epoch 11/20, Loss: 0.2206, Accuracy: 0.9369
# Epoch 12/20, Loss: 0.2091, Accuracy: 0.9399
# Epoch 13/20, Loss: 0.1988, Accuracy: 0.9431
# Epoch 14/20, Loss: 0.1889, Accuracy: 0.9462
# Epoch 15/20, Loss: 0.1802, Accuracy: 0.9487
# Epoch 16/20, Loss: 0.1721, Accuracy: 0.9501
# Epoch 17/20, Loss: 0.1643, Accuracy: 0.9525
# Epoch 18/20, Loss: 0.1576, Accuracy: 0.9543
# Epoch 19/20, Loss: 0.1510, Accuracy: 0.9564
# Epoch 20/20, Loss: 0.1450, Accuracy: 0.9577
#
# Testing leaky_relu + adam + LR=0.01
# Epoch 1/20, Loss: 0.2440, Accuracy: 0.9264
# Epoch 2/20, Loss: 0.1395, Accuracy: 0.9599
# Epoch 3/20, Loss: 0.1220, Accuracy: 0.9647
# Epoch 4/20, Loss: 0.1078, Accuracy: 0.9690
# Epoch 5/20, Loss: 0.0974, Accuracy: 0.9737
# Epoch 6/20, Loss: 0.0903, Accuracy: 0.9750
# Epoch 7/20, Loss: 0.0928, Accuracy: 0.9752
# Epoch 8/20, Loss: 0.0793, Accuracy: 0.9782
# Epoch 9/20, Loss: 0.0726, Accuracy: 0.9795
# Epoch 10/20, Loss: 0.0648, Accuracy: 0.9813
# Epoch 11/20, Loss: 0.0622, Accuracy: 0.9827
# Epoch 12/20, Loss: 0.0619, Accuracy: 0.9828
# Epoch 13/20, Loss: 0.0547, Accuracy: 0.9839
# Epoch 14/20, Loss: 0.0463, Accuracy: 0.9864
# Epoch 15/20, Loss: 0.0494, Accuracy: 0.9864
# Epoch 16/20, Loss: 0.0478, Accuracy: 0.9868
# Epoch 17/20, Loss: 0.0466, Accuracy: 0.9868
# Epoch 18/20, Loss: 0.0399, Accuracy: 0.9888
# Epoch 19/20, Loss: 0.0363, Accuracy: 0.9891
# Epoch 20/20, Loss: 0.0347, Accuracy: 0.9899
#
# Testing leaky_relu + adam + LR=0.001
# Epoch 1/20, Loss: 0.3385, Accuracy: 0.9062
# Epoch 2/20, Loss: 0.1403, Accuracy: 0.9577
# Epoch 3/20, Loss: 0.0957, Accuracy: 0.9708
# Epoch 4/20, Loss: 0.0734, Accuracy: 0.9775
# Epoch 5/20, Loss: 0.0566, Accuracy: 0.9820
# Epoch 6/20, Loss: 0.0461, Accuracy: 0.9856
# Epoch 7/20, Loss: 0.0358, Accuracy: 0.9888
# Epoch 8/20, Loss: 0.0317, Accuracy: 0.9901
# Epoch 9/20, Loss: 0.0261, Accuracy: 0.9915
# Epoch 10/20, Loss: 0.0209, Accuracy: 0.9934
# Epoch 11/20, Loss: 0.0186, Accuracy: 0.9943
# Epoch 12/20, Loss: 0.0164, Accuracy: 0.9945
# Epoch 13/20, Loss: 0.0155, Accuracy: 0.9947
# Epoch 14/20, Loss: 0.0135, Accuracy: 0.9953
# Epoch 15/20, Loss: 0.0112, Accuracy: 0.9964
# Epoch 16/20, Loss: 0.0107, Accuracy: 0.9964
# Epoch 17/20, Loss: 0.0120, Accuracy: 0.9959
# Epoch 18/20, Loss: 0.0088, Accuracy: 0.9970
# Epoch 19/20, Loss: 0.0110, Accuracy: 0.9960
# Epoch 20/20, Loss: 0.0073, Accuracy: 0.9976
#
# Testing selu + sgd + LR=0.01
# Epoch 1/20, Loss: 0.9889, Accuracy: 0.7731
# Epoch 2/20, Loss: 0.4021, Accuracy: 0.8905
# Epoch 3/20, Loss: 0.3353, Accuracy: 0.9056
# Epoch 4/20, Loss: 0.3062, Accuracy: 0.9123
# Epoch 5/20, Loss: 0.2886, Accuracy: 0.9181
# Epoch 6/20, Loss: 0.2751, Accuracy: 0.9212
# Epoch 7/20, Loss: 0.2640, Accuracy: 0.9243
# Epoch 8/20, Loss: 0.2546, Accuracy: 0.9273
# Epoch 9/20, Loss: 0.2456, Accuracy: 0.9298
# Epoch 10/20, Loss: 0.2373, Accuracy: 0.9320
# Epoch 11/20, Loss: 0.2288, Accuracy: 0.9346
# Epoch 12/20, Loss: 0.2201, Accuracy: 0.9376
# Epoch 13/20, Loss: 0.2122, Accuracy: 0.9400
# Epoch 14/20, Loss: 0.2042, Accuracy: 0.9421
# Epoch 15/20, Loss: 0.1965, Accuracy: 0.9449
# Epoch 16/20, Loss: 0.1890, Accuracy: 0.9469
# Epoch 17/20, Loss: 0.1819, Accuracy: 0.9485
# Epoch 18/20, Loss: 0.1749, Accuracy: 0.9508
# Epoch 19/20, Loss: 0.1685, Accuracy: 0.9522
# Epoch 20/20, Loss: 0.1623, Accuracy: 0.9545
#
# Testing selu + sgd + LR=0.001
# Epoch 1/20, Loss: 2.1131, Accuracy: 0.4265
# Epoch 2/20, Loss: 1.6785, Accuracy: 0.6975
# Epoch 3/20, Loss: 1.2516, Accuracy: 0.7580
# Epoch 4/20, Loss: 0.9604, Accuracy: 0.8000
# Epoch 5/20, Loss: 0.7852, Accuracy: 0.8272
# Epoch 6/20, Loss: 0.6753, Accuracy: 0.8428
# Epoch 7/20, Loss: 0.6021, Accuracy: 0.8547
# Epoch 8/20, Loss: 0.5501, Accuracy: 0.8629
# Epoch 9/20, Loss: 0.5115, Accuracy: 0.8692
# Epoch 10/20, Loss: 0.4819, Accuracy: 0.8753
# Epoch 11/20, Loss: 0.4584, Accuracy: 0.8790
# Epoch 12/20, Loss: 0.4393, Accuracy: 0.8829
# Epoch 13/20, Loss: 0.4234, Accuracy: 0.8862
# Epoch 14/20, Loss: 0.4103, Accuracy: 0.8889
# Epoch 15/20, Loss: 0.3990, Accuracy: 0.8914
# Epoch 16/20, Loss: 0.3890, Accuracy: 0.8936
# Epoch 17/20, Loss: 0.3805, Accuracy: 0.8951
# Epoch 18/20, Loss: 0.3729, Accuracy: 0.8969
# Epoch 19/20, Loss: 0.3662, Accuracy: 0.8982
# Epoch 20/20, Loss: 0.3600, Accuracy: 0.9001
#
# Testing selu + momentum + LR=0.01
# Epoch 1/20, Loss: 0.4082, Accuracy: 0.8845
# Epoch 2/20, Loss: 0.2232, Accuracy: 0.9348
# Epoch 3/20, Loss: 0.1668, Accuracy: 0.9504
# Epoch 4/20, Loss: 0.1331, Accuracy: 0.9606
# Epoch 5/20, Loss: 0.1113, Accuracy: 0.9667
# Epoch 6/20, Loss: 0.0946, Accuracy: 0.9715
# Epoch 7/20, Loss: 0.0837, Accuracy: 0.9747
# Epoch 8/20, Loss: 0.0734, Accuracy: 0.9776
# Epoch 9/20, Loss: 0.0660, Accuracy: 0.9800
# Epoch 10/20, Loss: 0.0584, Accuracy: 0.9814
# Epoch 11/20, Loss: 0.0517, Accuracy: 0.9837
# Epoch 12/20, Loss: 0.0464, Accuracy: 0.9858
# Epoch 13/20, Loss: 0.0416, Accuracy: 0.9873
# Epoch 14/20, Loss: 0.0377, Accuracy: 0.9887
# Epoch 15/20, Loss: 0.0339, Accuracy: 0.9896
# Epoch 16/20, Loss: 0.0308, Accuracy: 0.9906
# Epoch 17/20, Loss: 0.0273, Accuracy: 0.9918
# Epoch 18/20, Loss: 0.0243, Accuracy: 0.9927
# Epoch 19/20, Loss: 0.0223, Accuracy: 0.9931
# Epoch 20/20, Loss: 0.0198, Accuracy: 0.9943
#
# Testing selu + momentum + LR=0.001
# Epoch 1/20, Loss: 1.0078, Accuracy: 0.7510
# Epoch 2/20, Loss: 0.4131, Accuracy: 0.8876
# Epoch 3/20, Loss: 0.3401, Accuracy: 0.9036
# Epoch 4/20, Loss: 0.3096, Accuracy: 0.9112
# Epoch 5/20, Loss: 0.2905, Accuracy: 0.9166
# Epoch 6/20, Loss: 0.2763, Accuracy: 0.9209
# Epoch 7/20, Loss: 0.2642, Accuracy: 0.9246
# Epoch 8/20, Loss: 0.2536, Accuracy: 0.9274
# Epoch 9/20, Loss: 0.2436, Accuracy: 0.9305
# Epoch 10/20, Loss: 0.2347, Accuracy: 0.9331
# Epoch 11/20, Loss: 0.2258, Accuracy: 0.9359
# Epoch 12/20, Loss: 0.2176, Accuracy: 0.9380
# Epoch 13/20, Loss: 0.2093, Accuracy: 0.9404
# Epoch 14/20, Loss: 0.2015, Accuracy: 0.9434
# Epoch 15/20, Loss: 0.1940, Accuracy: 0.9450
# Epoch 16/20, Loss: 0.1865, Accuracy: 0.9472
# Epoch 17/20, Loss: 0.1797, Accuracy: 0.9486
# Epoch 18/20, Loss: 0.1732, Accuracy: 0.9504
# Epoch 19/20, Loss: 0.1665, Accuracy: 0.9524
# Epoch 20/20, Loss: 0.1606, Accuracy: 0.9541
#
# Testing selu + adam + LR=0.01
# Epoch 1/20, Loss: 0.2922, Accuracy: 0.9153
# Epoch 2/20, Loss: 0.1901, Accuracy: 0.9494
# Epoch 3/20, Loss: 0.1715, Accuracy: 0.9570
# Epoch 4/20, Loss: 0.1475, Accuracy: 0.9639
# Epoch 5/20, Loss: 0.1402, Accuracy: 0.9663
# Epoch 6/20, Loss: 0.1350, Accuracy: 0.9688
# Epoch 7/20, Loss: 0.1223, Accuracy: 0.9719
# Epoch 8/20, Loss: 0.1154, Accuracy: 0.9740
# Epoch 9/20, Loss: 0.1203, Accuracy: 0.9738
# Epoch 10/20, Loss: 0.1136, Accuracy: 0.9758
# Epoch 11/20, Loss: 0.1103, Accuracy: 0.9765
# Epoch 12/20, Loss: 0.1055, Accuracy: 0.9784
# Epoch 13/20, Loss: 0.1015, Accuracy: 0.9797
# Epoch 14/20, Loss: 0.1021, Accuracy: 0.9804
# Epoch 15/20, Loss: 0.0998, Accuracy: 0.9806
# Epoch 16/20, Loss: 0.0935, Accuracy: 0.9821
# Epoch 17/20, Loss: 0.1111, Accuracy: 0.9806
# Epoch 18/20, Loss: 0.0810, Accuracy: 0.9836
# Epoch 19/20, Loss: 0.0932, Accuracy: 0.9826
# Epoch 20/20, Loss: 0.0853, Accuracy: 0.9836
#
# Testing selu + adam + LR=0.001
# Epoch 1/20, Loss: 0.3225, Accuracy: 0.9072
# Epoch 2/20, Loss: 0.1593, Accuracy: 0.9516
# Epoch 3/20, Loss: 0.1102, Accuracy: 0.9665
# Epoch 4/20, Loss: 0.0842, Accuracy: 0.9738
# Epoch 5/20, Loss: 0.0687, Accuracy: 0.9779
# Epoch 6/20, Loss: 0.0546, Accuracy: 0.9823
# Epoch 7/20, Loss: 0.0435, Accuracy: 0.9859
# Epoch 8/20, Loss: 0.0379, Accuracy: 0.9873
# Epoch 9/20, Loss: 0.0310, Accuracy: 0.9892
# Epoch 10/20, Loss: 0.0276, Accuracy: 0.9906
# Epoch 11/20, Loss: 0.0222, Accuracy: 0.9923
# Epoch 12/20, Loss: 0.0173, Accuracy: 0.9944
# Epoch 13/20, Loss: 0.0170, Accuracy: 0.9942
# Epoch 14/20, Loss: 0.0159, Accuracy: 0.9947
# Epoch 15/20, Loss: 0.0153, Accuracy: 0.9947
# Epoch 16/20, Loss: 0.0115, Accuracy: 0.9961
# Epoch 17/20, Loss: 0.0102, Accuracy: 0.9965
# Epoch 18/20, Loss: 0.0104, Accuracy: 0.9960
# Epoch 19/20, Loss: 0.0121, Accuracy: 0.9960
# Epoch 20/20, Loss: 0.0091, Accuracy: 0.9967
#
# Testing elu + sgd + LR=0.01
# Epoch 1/20, Loss: 1.3636, Accuracy: 0.6837
# Epoch 2/20, Loss: 0.4973, Accuracy: 0.8654
# Epoch 3/20, Loss: 0.3856, Accuracy: 0.8914
# Epoch 4/20, Loss: 0.3467, Accuracy: 0.9013
# Epoch 5/20, Loss: 0.3247, Accuracy: 0.9071
# Epoch 6/20, Loss: 0.3090, Accuracy: 0.9114
# Epoch 7/20, Loss: 0.2967, Accuracy: 0.9152
# Epoch 8/20, Loss: 0.2866, Accuracy: 0.9178
# Epoch 9/20, Loss: 0.2776, Accuracy: 0.9205
# Epoch 10/20, Loss: 0.2694, Accuracy: 0.9227
# Epoch 11/20, Loss: 0.2617, Accuracy: 0.9254
# Epoch 12/20, Loss: 0.2538, Accuracy: 0.9270
# Epoch 13/20, Loss: 0.2466, Accuracy: 0.9299
# Epoch 14/20, Loss: 0.2390, Accuracy: 0.9320
# Epoch 15/20, Loss: 0.2314, Accuracy: 0.9335
# Epoch 16/20, Loss: 0.2241, Accuracy: 0.9364
# Epoch 17/20, Loss: 0.2168, Accuracy: 0.9387
# Epoch 18/20, Loss: 0.2099, Accuracy: 0.9404
# Epoch 19/20, Loss: 0.2030, Accuracy: 0.9433
# Epoch 20/20, Loss: 0.1965, Accuracy: 0.9443
#
# Testing elu + sgd + LR=0.001
# Epoch 1/20, Loss: 2.2380, Accuracy: 0.2901
# Epoch 2/20, Loss: 2.1078, Accuracy: 0.5691
# Epoch 3/20, Loss: 1.9177, Accuracy: 0.6614
# Epoch 4/20, Loss: 1.6542, Accuracy: 0.6839
# Epoch 5/20, Loss: 1.3709, Accuracy: 0.7084
# Epoch 6/20, Loss: 1.1307, Accuracy: 0.7456
# Epoch 7/20, Loss: 0.9506, Accuracy: 0.7803
# Epoch 8/20, Loss: 0.8212, Accuracy: 0.8045
# Epoch 9/20, Loss: 0.7280, Accuracy: 0.8210
# Epoch 10/20, Loss: 0.6586, Accuracy: 0.8332
# Epoch 11/20, Loss: 0.6059, Accuracy: 0.8437
# Epoch 12/20, Loss: 0.5647, Accuracy: 0.8524
# Epoch 13/20, Loss: 0.5316, Accuracy: 0.8600
# Epoch 14/20, Loss: 0.5048, Accuracy: 0.8655
# Epoch 15/20, Loss: 0.4826, Accuracy: 0.8700
# Epoch 16/20, Loss: 0.4640, Accuracy: 0.8742
# Epoch 17/20, Loss: 0.4486, Accuracy: 0.8775
# Epoch 18/20, Loss: 0.4350, Accuracy: 0.8807
# Epoch 19/20, Loss: 0.4234, Accuracy: 0.8832
# Epoch 20/20, Loss: 0.4130, Accuracy: 0.8853
#
# Testing elu + momentum + LR=0.01
# Epoch 1/20, Loss: 0.4899, Accuracy: 0.8624
# Epoch 2/20, Loss: 0.2456, Accuracy: 0.9276
# Epoch 3/20, Loss: 0.1810, Accuracy: 0.9466
# Epoch 4/20, Loss: 0.1419, Accuracy: 0.9583
# Epoch 5/20, Loss: 0.1165, Accuracy: 0.9655
# Epoch 6/20, Loss: 0.1000, Accuracy: 0.9695
# Epoch 7/20, Loss: 0.0868, Accuracy: 0.9741
# Epoch 8/20, Loss: 0.0759, Accuracy: 0.9768
# Epoch 9/20, Loss: 0.0681, Accuracy: 0.9791
# Epoch 10/20, Loss: 0.0610, Accuracy: 0.9815
# Epoch 11/20, Loss: 0.0548, Accuracy: 0.9835
# Epoch 12/20, Loss: 0.0490, Accuracy: 0.9850
# Epoch 13/20, Loss: 0.0440, Accuracy: 0.9864
# Epoch 14/20, Loss: 0.0400, Accuracy: 0.9877
# Epoch 15/20, Loss: 0.0361, Accuracy: 0.9890
# Epoch 16/20, Loss: 0.0334, Accuracy: 0.9903
# Epoch 17/20, Loss: 0.0294, Accuracy: 0.9912
# Epoch 18/20, Loss: 0.0260, Accuracy: 0.9924
# Epoch 19/20, Loss: 0.0244, Accuracy: 0.9928
# Epoch 20/20, Loss: 0.0219, Accuracy: 0.9938
#
# Testing elu + momentum + LR=0.001
# Epoch 1/20, Loss: 1.3852, Accuracy: 0.6818
# Epoch 2/20, Loss: 0.4901, Accuracy: 0.8687
# Epoch 3/20, Loss: 0.3815, Accuracy: 0.8923
# Epoch 4/20, Loss: 0.3422, Accuracy: 0.9023
# Epoch 5/20, Loss: 0.3195, Accuracy: 0.9085
# Epoch 6/20, Loss: 0.3039, Accuracy: 0.9125
# Epoch 7/20, Loss: 0.2923, Accuracy: 0.9158
# Epoch 8/20, Loss: 0.2820, Accuracy: 0.9189
# Epoch 9/20, Loss: 0.2735, Accuracy: 0.9207
# Epoch 10/20, Loss: 0.2654, Accuracy: 0.9237
# Epoch 11/20, Loss: 0.2576, Accuracy: 0.9248
# Epoch 12/20, Loss: 0.2502, Accuracy: 0.9277
# Epoch 13/20, Loss: 0.2427, Accuracy: 0.9294
# Epoch 14/20, Loss: 0.2352, Accuracy: 0.9322
# Epoch 15/20, Loss: 0.2277, Accuracy: 0.9342
# Epoch 16/20, Loss: 0.2209, Accuracy: 0.9362
# Epoch 17/20, Loss: 0.2136, Accuracy: 0.9378
# Epoch 18/20, Loss: 0.2067, Accuracy: 0.9408
# Epoch 19/20, Loss: 0.2003, Accuracy: 0.9425
# Epoch 20/20, Loss: 0.1942, Accuracy: 0.9444
#
# Testing elu + adam + LR=0.01
# Epoch 1/20, Loss: 0.2559, Accuracy: 0.9236
# Epoch 2/20, Loss: 0.1542, Accuracy: 0.9573
# Epoch 3/20, Loss: 0.1332, Accuracy: 0.9636
# Epoch 4/20, Loss: 0.1220, Accuracy: 0.9667
# Epoch 5/20, Loss: 0.1133, Accuracy: 0.9699
# Epoch 6/20, Loss: 0.1163, Accuracy: 0.9708
# Epoch 7/20, Loss: 0.1049, Accuracy: 0.9736
# Epoch 8/20, Loss: 0.0914, Accuracy: 0.9767
# Epoch 9/20, Loss: 0.0871, Accuracy: 0.9775
# Epoch 10/20, Loss: 0.0903, Accuracy: 0.9785
# Epoch 11/20, Loss: 0.0900, Accuracy: 0.9795
# Epoch 12/20, Loss: 0.0920, Accuracy: 0.9798
# Epoch 13/20, Loss: 0.0867, Accuracy: 0.9807
# Epoch 14/20, Loss: 0.0788, Accuracy: 0.9826
# Epoch 15/20, Loss: 0.0770, Accuracy: 0.9833
# Epoch 16/20, Loss: 0.0860, Accuracy: 0.9820
# Epoch 17/20, Loss: 0.0785, Accuracy: 0.9840
# Epoch 18/20, Loss: 0.0607, Accuracy: 0.9870
# Epoch 19/20, Loss: 0.0820, Accuracy: 0.9839
# Epoch 20/20, Loss: 0.0858, Accuracy: 0.9829
#
# Testing elu + adam + LR=0.001
# Epoch 1/20, Loss: 0.3320, Accuracy: 0.9052
# Epoch 2/20, Loss: 0.1489, Accuracy: 0.9557
# Epoch 3/20, Loss: 0.1011, Accuracy: 0.9695
# Epoch 4/20, Loss: 0.0766, Accuracy: 0.9762
# Epoch 5/20, Loss: 0.0603, Accuracy: 0.9807
# Epoch 6/20, Loss: 0.0488, Accuracy: 0.9839
# Epoch 7/20, Loss: 0.0403, Accuracy: 0.9871
# Epoch 8/20, Loss: 0.0331, Accuracy: 0.9889
# Epoch 9/20, Loss: 0.0270, Accuracy: 0.9911
# Epoch 10/20, Loss: 0.0213, Accuracy: 0.9931
# Epoch 11/20, Loss: 0.0183, Accuracy: 0.9939
# Epoch 12/20, Loss: 0.0171, Accuracy: 0.9941
# Epoch 13/20, Loss: 0.0145, Accuracy: 0.9953
# Epoch 14/20, Loss: 0.0121, Accuracy: 0.9961
# Epoch 15/20, Loss: 0.0111, Accuracy: 0.9962
# Epoch 16/20, Loss: 0.0101, Accuracy: 0.9964
# Epoch 17/20, Loss: 0.0083, Accuracy: 0.9974
# Epoch 18/20, Loss: 0.0104, Accuracy: 0.9963
# Epoch 19/20, Loss: 0.0086, Accuracy: 0.9968
# Epoch 20/20, Loss: 0.0077, Accuracy: 0.9975
#
# Best Combination:
# Activation Function: tanh
# Optimizer: adam
# Learning Rate: 0.001
# Best Accuracy: 0.9994

# %%
# Run your experiments here ...

# optimizers = ['sgd', 'momentum', 'adam']
# activation_functions = ['relu', 'tanh', 'sigmoid', 'leaky_relu', 'selu', 'elu']
# learning_rates = [1e-2, 1e-3]
# num_epoch = 10
# sizes = [784, 128, 64, 10]

# results = []

# for ac_fn in activation_functions:
#     for opt in optimizers:
#         for lr in learning_rates:
#             print(f"Training with Activation: {ac_fn}, Optimizer: {opt}, Learning Rate: {lr}")
#             model = MLP(sizes=sizes, activation = ac_fn)
#             model.train(np.array(x_train[:55000]), y_train[:55000], x_train[55000:], y_train[55000:], epochs=num_epoch, l_rate=lr)
#             model.evaluate(x_test, y_test)
#             results.append({
#                 'act': ac_fn,
#                 'opt': opt,
#                 'lr' : lr,
#                 'test acc': model.accuracy(y_test, model.feed_forward(x_test)),
#                 'train acc': model.accuracy(y_train, model.feed_forward(x_train))
#             })

'''
its a simpler way to train & evaluate our model, using your codes, but that's didn't run for me for the sake of GOD! and i wrote some functions myself (that you saw above)
accept my apologize from here <3
'''
# Out:
# Training with Activation: relu, Optimizer: sgd, Learning Rate: 0.01
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-2c7feb65ad66> in <cell line: 10>()
#      13             print(f"Training with Activation: {ac_fn}, Optimizer: {opt}, Learning Rate: {lr}")
#      14             model = MLP(sizes=sizes, activation = ac_fn)
# ---> 15             model.train(np.array(x_train[:55000]), y_train[:55000], x_train[55000:], y_train[55000:], epochs=num_epoch, l_rate=lr)
#      16             model.evaluate(x_test, y_test)
#      17             results.append({
#
# <ipython-input-6-d035696073b7> in train(self, x_train, y_train, x_val, y_val, epochs, batch_size, optimizer, l_rate, beta, beta1, beta2, epsilon, t)
#     292             permutation = np.random.permutation(x_train.shape[0])
#     293             x_train_shuffled = x_train[permutation]
# --> 294             y_train_shuffled = y_train[permutation]
#     295
#     296             for j in range(num_batches):
#
# IndexError: index 47921 is out of bounds for dimension 0 with size 3200

# %% [markdown]
# # MLP as function Approximator
# We know that a MLP with one hidden layer could  approximate any smooth function! <br> Here you will manually fit a sine function using ReLU activation. <br>You need to set the correct weights on ReLUs so the linear combination approximates the desired function.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

''' The real function which you wrote, had some problems for me, and i rewrite it :(( Sorry! '''

def plot_function_apx(x_points, activation_map, predicted_output):
    """Plot the ReLU activations and the predicted output"""
    plt.figure(figsize=(10, 6))
    plt.subplot(1, 2, 1)

    for i in range(activation_map.shape[0]):
      plt.plot(x_points, activation_map[i, :].detach().numpy(), label=f"ReLU Unit {i+1}")

    plt.title('ReLU Activations')
    plt.xlabel('x')
    plt.ylabel('Activation')
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(x_points, torch.sin(x_points), label='Ground Truth (sin(x))', color='g', linewidth=2)
    plt.plot(x_points, predicted_output.detach().numpy(), label="Predicted Output", color='r')
    plt.title('Predicted Function Approximation')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def relu_approximation(input_data, target_labels):
    """
    Args:
      input_data: torch.tensor
        Input training data
      target_labels: torch.tensor
        Ground truth labels for training data

    Returns:
      activation_map: torch.tensor
        ReLU activations computed across the x-axis
      predicted_labels: torch.tensor
        Estimated labels or class predictions
        Derived from weighted sum of ReLU activations along the x-axis
      x_points: torch.tensor
        Points along the x-axis
    """
    ##############################---TODO---##############################
    # Number of ReLU units
    num_relus = input_data.shape[0] - 1

    # Generate dense x-axis points for interpolation
    x_points = torch.linspace(torch.min(input_data), torch.max(input_data), 1000)

    # Compute bias for ReLU units
    biases = []

    for i in range(1, len(input_data)):
        biases.append((input_data[i - 1]))

    # Initialize activation map to store ReLU activations
    activation_map = torch.zeros(num_relus, 1000)

    for relu_idx in range(num_relus):
        activation_map[relu_idx, :] = torch.relu(x_points - biases[relu_idx])

    ## WEIGHTED SUM OF RELUS

    relu_weights = torch.zeros(num_relus)
    previous_slope = 0
    dist = input_data[1] - input_data[0]
    for j in range(num_relus):
        m = (target_labels[j + 1] - target_labels[j]) / dist
        relu_weights[j] = m - previous_slope
        previous_slope = m

    # Compute predicted labels as weighted sum of ReLU activations
    predicted_labels = relu_weights @ activation_map
    ##############################---TODO---##############################

    return predicted_labels, activation_map, x_points

# Generate synthetic training data using sine function
num_samples = 10
input_data = torch.linspace(0, 2 * np.pi, num_samples).view(-1, 1)
target_labels = torch.sin(input_data)

# Run the approximation
predicted_output, activation_map, x_points = relu_approximation(input_data, target_labels)

plot_function_apx(x_points, activation_map, predicted_output)

# %% [markdown]
# # Depth vs. Width
# Here we wanna see the effect of width vs. depth on a classification task.First you are going to implement MLP again; But with 2 differences: <br>
#
# 1.   It is general purpose (i.e. works for desired depth and activation functions)
# 2.   You will implement it using pytorch

# %%
class MLP_pytorch(nn.Module):
  """
  Simulate MLP Network
  """

  def __init__(self, activation_fn, input_feature_num, hidden_unit_nums, output_feature_num):
    """
    Initialize MLP Network parameters

    Args:
      activation_fn: string
        Activation function
      input_feature_num: int
        Number of input features
      hidden_unit_nums: list
        Number of units per hidden layer. List of integers
      output_feature_num: int
        Number of output features

    Returns:
      Nothing
    """
    super(MLP_pytorch, self).__init__()
    self.input_feature_num = input_feature_num
    self.mlp = nn.Sequential()

    if activation_fn == 'ReLU':
            self.activation_fn = nn.ReLU()
    elif activation_fn == 'Sigmoid':
            self.activation_fn = nn.Sigmoid()
    elif activation_fn == 'Tanh':
            self.activation_fn = nn.Tanh()
    elif activation_fn == 'LeakyReLU':
            self.activation_fn = nn.LeakyReLU()
    elif activation_fn == 'ELU':
            self.activation_fn = nn.ELU()

    in_num = input_feature_num
    ##############################---TODO---##############################

    for i, hidden_units in enumerate(hidden_unit_nums):
            # Add the hidden layer
            self.mlp.add_module(f'Hidden_{i+1}_Linear', nn.Linear(in_num, hidden_units))
            self.mlp.add_module(f'Hidden_{i+1}_Activation', self.activation_fn)
            # Update input size for next layer
            in_num = hidden_units

    out_layer = nn.Linear(in_num, output_feature_num) # final layer
    self.mlp.add_module('Output_Linear', out_layer)

    ##############################---TODO---##############################

  def forward(self, x):
    """
    Simulate forward pass of MLP Network

    Args:
      x: torch.tensor
        Input data

    Returns:
      logits: Instance of MLP
        Forward pass of MLP
    """
    # Reshape inputs to (batch_size, input_feature_num)
    x = x.view(-1, self.input_feature_num)
    logits = self.mlp(x) # forward pass

    return logits

# %% [markdown]
# Now let's make a spiral dataset that follows this formula:
# \begin{equation}
# \begin{array}{c}
# X_{k}(t)=t\left(\begin{array}{c}
# \sin \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right) \\
# \cos \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right)
# \end{array}\right)
# \end{array}, \quad 0 \leq t \leq 1, \quad k=1, \ldots, K
# \end{equation}
#
# Run cell below to create the data and load it as tensors.

# %%
# @title Data Loader
K = 4
sigma = 0.4
N = 1000
t = torch.linspace(0, 1, N)
X = torch.zeros(K*N, 2)
y = torch.zeros(K*N)
for k in range(K):
  X[k*N:(k+1)*N, 0] = t*(torch.sin(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  X[k*N:(k+1)*N, 1] = t*(torch.cos(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  y[k*N:(k+1)*N] = k


X_test, y_test, X_train, y_train = shuffle_and_split_data(X, y, seed=SEED)

# DataLoader with random seed
batch_size = 128
g_seed = torch.Generator()
g_seed.manual_seed(SEED)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=batch_size,
                         shuffle=False, num_workers=0,
                         worker_init_fn=seed_worker,
                         generator=g_seed,
                         )

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data,
                          batch_size=batch_size,
                          drop_last=True,
                          shuffle=True,
                          worker_init_fn=seed_worker,
                          generator=g_seed,
                          )

# %% [markdown]
# Now we will add more polynomial features to the dataset to make the first layer wider. Afterwards, train a single linear layer. We could use the same MLP network with no hidden layers (though it would not be called an MLP anymore!).
#
# Add polynomial terms up to $P=50$ which means that for every $x_1^n x_2^m$ term, $n+m\leq P$. Total number of polynomial features up to $P$ follows this formula:
#
# \begin{equation}
# \text{# of terms} = \frac{(P+1)(P+2)}{2}
# \end{equation}
#
# Also, we don't need the polynomial term with degree zero (which is the constatnt term) since `nn.Linear` layers have bias terms. Therefore we will have one fewer polynomial feature.

# %%
def polynomial_classifier(poly_degree, seed=0):
  """
  Helper function to run the polynomial classifier

  Args:
    poly_degree: int
      Degree of the polynomial
    seed: int
      A non-negative integer that defines the random state.

  Returns:
    num_features: int
      Number of features
  """

  def polynomial_features(poly_degree, X):
    """
    Function to define the number of polynomial features except the bias term

    Args:
      poly_degree: int
        Degree of the polynomial
      X: torch.tensor
        Input data

    Returns:
      num_features: int
        Number of features
      poly_X: torch.tensor
        Polynomial term
    """
    ##############################---TODO---##############################

    # num_samples, num_features = X.shape
    # poly_terms = []
    # for degree in range(1, poly_degree + 1):
    #     for n in range(degree + 1):
    #         m = degree - n
    #         poly_terms.append((n, m))

    # num_features = len(poly_terms)
    # poly_X = torch.zeros(num_samples, num_features)

    # for idx, (n, m) in enumerate(poly_terms):
    #     poly_X[:, idx] = (X[:, 0]**n) * (X[:, 1]**m)

    num_samples = X.size(0)
    num_features = (poly_degree + 1) * (poly_degree + 2) // 2 - 1
    poly_X = torch.zeros(num_samples, num_features)

    idx = 0
    for degree_x in range(poly_degree + 1):
        for degree_y in range(poly_degree + 1 - degree_x):  # n + m <= P
            if degree_x == 0 and degree_y == 0:
                continue  # Skip constant term
            poly_X[:, idx] = (X[:, 0] ** degree_x) * (X[:, 1] ** degree_y)
            idx += 1

    return poly_X, num_features
    ##############################---TODO---##############################

  poly_X_test, num_features = polynomial_features(poly_degree, X_test)
  poly_X_train, _ = polynomial_features(poly_degree, X_train)

  batch_size = 128

  g_seed = torch.Generator()
  g_seed.manual_seed(seed)
  poly_test_data = TensorDataset(poly_X_test, y_test)
  poly_test_loader = DataLoader(poly_test_data,
                                batch_size=batch_size,
                                shuffle=False,
                                num_workers=1,
                                worker_init_fn=seed_worker,
                                generator=g_seed)

  poly_train_data = TensorDataset(poly_X_train, y_train)
  poly_train_loader = DataLoader(poly_train_data,
                                 batch_size=batch_size,
                                 shuffle=True,
                                 num_workers=1,
                                 worker_init_fn=seed_worker,
                                 generator=g_seed)

  # Defining a linear model using MLP class
  poly_net = MLP_pytorch('ReLU()', num_features, [], K)

  # Train and test
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(poly_net.parameters(), lr=1e-3)
  _, _ = train_test_classification(poly_net, criterion, optimizer,
                                   poly_train_loader, poly_test_loader,
                                   num_epochs=100)
  X_all = sample_grid()
  poly_X_all, _ = polynomial_features(poly_degree, X_all)
  y_pred = poly_net(poly_X_all)

  # Plot
  plot_decision_map(X_all.cpu(), y_pred.cpu(), X_test.cpu(), y_test.cpu())
  plt.show()

  return num_features

# %% [markdown]
# ### Train the network. How does it generalize?

# %%
seed_setter(seed=SEED)
max_poly_deg = 50
num_features = polynomial_classifier(max_poly_deg)
print(f'Number of features: {num_features}')
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 69.59
# Accuracy on the 800 testing samples: 70.12
# Number of features: 1325

# %% [markdown]
# Now create another instance of `MLP_pytorch` class having a hidden layer of 128 neurons and train it. Compare the result with the wide network. How does deeper model generalize? Is the decision boundaries ideal? Why?

# %%
##############################---TODO---##############################
seed_setter(SEED)

net2 = MLP_pytorch(activation_fn="ReLU", input_feature_num=2, hidden_unit_nums=[128], output_feature_num=K)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net2.parameters(), lr=1e-3)

num_epochs = 100

_, _ = train_test_classification(net2, criterion, optimizer, train_loader, test_loader, num_epochs=num_epochs, training_plot=True,)

X_all = sample_grid()
y_pred = net2(X_all).cpu()

plot_decision_map(X_all, y_pred, X_test, y_test)
##############################---TODO---##############################
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 97.88
# Accuracy on the 800 testing samples: 97.88
